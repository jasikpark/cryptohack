# %%
from Crypto.Util.number import *

long_to_bytes(11515195063862318899931685488813747395775516287289682636499965282714637259206269)
# Out:
# b'crypto{3nc0d1n6_4ll_7h3_w4y_d0wn}'

# %% [markdown]
# XOR Starter

# %%
def xor(a,b):
  return a  ^ b

xor(0b0110, 0b1010)

text = "label"
ascii = [ord(c) for c in text]
xored = [xor(c,13) for c in ascii]
xored_text = [chr(c) for c in xored]
xored_text
# Out:
# ['a', 'l', 'o', 'h', 'a']

# %%
from pwn import xor


KEY1 = bytes.fromhex("a6c8b6733c9b22de7bc0253266a3867df55acde8635e19c73313")
KEY2_x_KEY1 = bytes.fromhex(
    "37dcb292030faa90d07eec17e3b1c6d8daf94c35d4c9191a5e1e")
KEY2 = xor(KEY1, KEY2_x_KEY1)
print(KEY2)
KEY2_x_KEY3 = bytes.fromhex(
    "c1545756687e7573db23aa1c3452a098b71a7fbf0fddddde5fc1")
KEY3 = xor(KEY2, KEY2_x_KEY3)
FLAG_x_KEY1_x_KEY3_x_KEY2 = bytes.fromhex(
    "04ee9855208a2cd59091d04767ae47963170d1660df7f56f5faf")
FLAG = xor(KEY1, KEY2, KEY3, FLAG_x_KEY1_x_KEY3_x_KEY2)
print(FLAG)
# Out:
# b'\x91\x14\x04\xe1?\x94\x88N\xab\xbe\xc9%\x85\x12@\xa5/\xa3\x81\xdd\xb7\x97\x00\xddm\r'
# b'crypto{x0r_i5_ass0c1at1v3}'

# %%
cipher = bytes.fromhex('73626960647f6b206821204f21254f7d694f7624662065622127234f726927756d')
from pwn import xor
[xor(n,cipher) for n in range(20)]
# Out:
# [b"sbi`d\x7fk h! O!%O}iOv$f eb!'#Ori'um",
#  b'rchae~j!i !N $N|hNw%g!dc &"Nsh&tl',
#  b'q`kbf}i"j#"M#\'M\x7fkMt&d"g`#%!Mpk%wo',
#  b'pajcg|h#k"#L"&L~jLu\'e#fa"$ Lqj$vn',
#  b"wfmd`{o$l%$K%!KymKr b$af%#'Kvm#qi",
#  b'vgleazn%m$%J$ JxlJs!c%`g$"&Jwl"ph',
#  b'udofbym&n\'&I\'#I{oIp"`&cd\'!%Ito!sk',
#  b'tengcxl\'o&\'H&"HznHq#a\'be& $Hun rj',
#  b'{jahlwc(`)(G)-GuaG~,n(mj)/+Gza/}e',
#  b'zk`imvb)a()F(,Ft`F\x7f-o)lk(.*F{`.|d',
#  b'yhcjnua*b+*E+/EwcE|.l*oh+-)Exc-\x7fg',
#  b'xibkot`+c*+D*.DvbD}/m+ni*,(Dyb,~f',
#  b'\x7fnelhsg,d-,C-)CqeCz(j,in-+/C~e+ya',
#  b'~odmirf-e,-B,(BpdB{)k-ho,*.B\x7fd*x`',
#  b'}lgnjqe.f/.A/+AsgAx*h.kl/)-A|g){c',
#  b'|mfokpd/g./@.*@rf@y+i/jm.(,@}f(zb',
#  b'crypto{0x10_15_my_f4v0ur173_by7e}',
#  b'bsxqunz1y01^04^lx^g5w1ts062^cx6d|',
#  b'ap{rvmy2z32]37]o{]d6t2wp351]`{5g\x7f',
#  b'`qzswlx3{23\\26\\nz\\e7u3vq240\\az4f~']

# %%
from pwn import xor
cipher = bytes.fromhex(
    '0e0b213f26041e480b26217f27342e175d0e070a3c5b103e2526217f27342e175d0e077e263451150104')

print('cipher', cipher)

def predicate(maybe_flag):
    print(maybe_flag[0:6])
    return maybe_flag[0:6] == 'crypto{'


list(filter(predicate, [xor(n, cipher) for n in range(256)]))
# Out:
# cipher b"\x0e\x0b!?&\x04\x1eH\x0b&!\x7f'4.\x17]\x0e\x07\n<[\x10>%&!\x7f'4.\x17]\x0e\x07~&4Q\x15\x01\x04"
# b'\x0e\x0b!?&\x04'
# b"\x0f\n >'\x05"
# b'\x0c\t#=$\x06'
# b'\r\x08"<%\x07'
# b'\n\x0f%;"\x00'
# b'\x0b\x0e$:#\x01'
# b"\x08\r'9 \x02"
# b'\t\x0c&8!\x03'
# b'\x06\x03)7.\x0c'
# b'\x07\x02(6/\r'
# b'\x04\x01+5,\x0e'
# b'\x05\x00*4-\x0f'
# b'\x02\x07-3*\x08'
# b'\x03\x06,2+\t'
# b'\x00\x05/1(\n'
# b'\x01\x04.0)\x0b'
# b'\x1e\x1b1/6\x14'
# b'\x1f\x1a0.7\x15'
# b'\x1c\x193-4\x16'
# b'\x1d\x182,5\x17'
# b'\x1a\x1f5+2\x10'
# b'\x1b\x1e4*3\x11'
# b'\x18\x1d7)0\x12'
# b'\x19\x1c6(1\x13'
# b"\x16\x139'>\x1c"
# b'\x17\x128&?\x1d'
# b'\x14\x11;%<\x1e'
# b'\x15\x10:$=\x1f'
# b'\x12\x17=#:\x18'
# b'\x13\x16<";\x19'
# b'\x10\x15?!8\x1a'
# b'\x11\x14> 9\x1b'
# b'.+\x01\x1f\x06$'
# b'/*\x00\x1e\x07%'
# b',)\x03\x1d\x04&'
# b"-(\x02\x1c\x05'"
# b'*/\x05\x1b\x02 '
# b'+.\x04\x1a\x03!'
# b'(-\x07\x19\x00"'
# b'),\x06\x18\x01#'
# b'&#\t\x17\x0e,'
# b'\'"\x08\x16\x0f-'
# b'$!\x0b\x15\x0c.'
# ...
